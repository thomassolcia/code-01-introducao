# %% [markdown]
# <a href="https://colab.research.google.com/github/COMP3025/code-01-introducao/blob/master/aula-27-03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Exercício
#
# Olá! Vamos praticar alguns comandos através de exercícios _hands on_.

# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# Procurem três tipos de imagens:
#
# *   Uma imagem preto e branco;
# *   Uma imagem em tons de cinza;
# *   Uma imagem colorida, de extensão `jpg`.
#
# Salvem as imagens no GoogleDrive, e carreguem no script. Crie as seguintes variáveis: `imagem_pb`, `imagem_cinza` e `imagem_color`, carregue e "plote" as duas imagens.

# %%
# escreva o código aqui
imagem_pb = Image.open('/content/drive/My Drive/2020/COMP3025 - Computação Gráfica/images/Auto_Racing_White_Black.svg.png')
imagem_cinza = Image.open('/content/drive/My Drive/2020/COMP3025 - Computação Gráfica/images/renden-yoder-6yYUrFxKFck-unsplash.jpg')
imagem_color = Image.open('/content/drive/My Drive/2020/COMP3025 - Computação Gráfica/images/vincent-van-zalinge-_d0zgyMmYT8-unsplash.jpg')


plt.figure(figsize=(20,4))

plt.subplot(131) #131 1 linha 3 colunas posição 1
plt.title('Imagem p&b')
plt.axis('off')
plt.imshow(imagem_pb)

plt.subplot(132) #132 1 linha 3 colunas posição 2
plt.title('Imagem cinza')
plt.axis('off')
plt.axis('off')
plt.imshow(imagem_cinza)

plt.subplot(133) #133 1 linha 3 colunas posição 3
plt.title('Imagem colorida')
plt.axis('off')
plt.imshow(imagem_color)

plt.show()

# fig, (im1, im2, im3) = plt.subplots(1, 3)

# im1.imshow(imagem_pb)
# im1.axis(False)
# im1.set_title('Imagem p&b')

# im2.imshow(imagem_cinza)
# im2.axis(False)
# im2.set_title('Imagem cinza')

# im3.imshow(imagem_color)
# im3.axis(False)
# im3.set_title('Imagem colorida')

# %% [markdown]
# Realize uma análise exploratória dos dados das imagens, e responda as questões abaixo:

# %%
# escreva os códigos necessários para análise aqui, inclua pontos de códigos entre
# as questões, assim como incluam plots, tabelas, o que for necessário 
imagem_pb_arr = np.array(imagem_pb)
imagem_cinza_arr = np.array(imagem_cinza)
imagem_color_arr = np.array(imagem_color)

# imagem_cinza_arr.shape

# imagem_pb_arr[0:10,:,0].shape

imagem_color_arr.shape
# Out:
# (1218, 1827, 3)

# %%
# imagem_color_arr = np.array(imagem_color)

# img_pb = imagem_pb_arr

# im_cinza = imagem_cinza_arr
# im_cinza = 255 - im_cinza

# img_pb = 255 - img_pb

# img_pb[img_pb > 127] = 255
# img_pb[img_pb < 127] = 0

# plt.imshow(im_cinza)
# 
# red = imagem_color_arr[:,:,0]
# green = imagem_color_arr[:,:,1]
# blue = imagem_color_arr[:,:,2]

red1 = np.array(imagem_color)
red2 = np.array(imagem_color)
red1[:,:,(1,2)] = 0
red2[:,:,(1,2)] = 255

green1 = np.array(imagem_color)
green2 = np.array(imagem_color)
green1[:,:,(0,2)] = 0
green2[:,:,(0,2)] = 255

# green
blue1 = np.array(imagem_color)
blue2 = np.array(imagem_color)
blue1[:,:,(0,1)] = 0
blue2[:,:,(0,1)] = 255

plt.figure(figsize=(20,15))

plt.subplot(331) #131 1 linha 3 colunas posição 1
plt.axis('off')
plt.imshow(red1)

plt.subplot(332) #132 1 linha 3 colunas posição 2
plt.axis('off')
plt.imshow(green1)

plt.subplot(333) #133 1 linha 3 colunas posição 3
plt.axis('off')
plt.imshow(blue1)

plt.subplot(334) #131 1 linha 3 colunas posição 1
plt.axis('off')
plt.imshow(red2)

plt.subplot(335) #132 1 linha 3 colunas posição 2
plt.axis('off')
plt.imshow(green2)

plt.subplot(336) #133 1 linha 3 colunas posição 3
plt.axis('off')
plt.imshow(blue2)

plt.subplot(337) #133 1 linha 3 colunas posição 3
plt.axis('off')
plt.imshow(imagem_color)

plt.show()

# %%
imagem_color_arr = np.array(imagem_color)

red = imagem_color_arr[:,:,0]
green = imagem_color_arr[:,:,1]
blue = imagem_color_arr[:,:,2]

plt.figure(figsize=(12,4))

plt.subplot(131) #131 1 linha 3 colunas posição 1
plt.hist(red.ravel(), color='red')

plt.subplot(132) #132 1 linha 3 colunas posição 2
plt.hist(green.ravel(), color='green')

plt.subplot(133) #133 1 linha 3 colunas posição 3
plt.hist(blue.ravel(), color='blue')
# Out:
# (array([ 68063.,  46394., 213600., 712958., 410897., 212981., 166028.,
#         154608., 146416.,  93341.]),
#  array([  0. ,  23.4,  46.8,  70.2,  93.6, 117. , 140.4, 163.8, 187.2,
#         210.6, 234. ]),
#  <a list of 10 Patch objects>)

# %%
red.shape
# Out:
# (1218, 1827)

# %%
r= red2[:,:,0]
g=green2[:,:,1]
b=blue2[:,:,2]

inv = np.array([r,g,b])
inv = np.reshape(inv, (1218, 1827, 3))

plt.figure(figsize=(12,4))
plt.imshow(inv)

# %%
inv[:,:,0]
# Out:
# array([[249, 247, 251, ..., 195, 197, 192],
#        [247, 249, 249, ..., 200, 208, 201],
#        [251, 251, 249, ..., 195, 199, 188],
#        ...,
#        [137, 141, 138, ...,  94,  93, 100],
#        [141, 140, 140, ...,  98,  96,  96],
#        [146, 140, 138, ...,  91, 103,  96]], dtype=uint8)

# %%
c = [r.ravel(), g.ravel(), b.ravel()]
c_inv = c.reshape(c, (1218, 1827, 3))
c_inv

plt.imshow(c_inv)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-160-67b98bfef062> in <module>()
#       1 c = [r.ravel(), g.ravel(), b.ravel()]
# ----> 2 c_inv = c.reshape(1218, 1827, 3)
#       3 c_inv
#       4
#       5 plt.imshow(c_inv)
#
# AttributeError: 'list' object has no attribute 'reshape'

# %% [markdown]
# Qual o menor e maior valor das imagens:
#
# *   [pb]: min(0) e max(255)
# *   [cinza]: min(0) e max(255)
# *   [color]:
#     * [R]
#     * [G]
#     * [B]

# %% [markdown]
# Qual o valor da média imagens:
#
# *   [pb]:
# *   [cinza]:
# *   [color]:
#     * [R]
#     * [G]
#     * [B]

# %% [markdown]
# Qual o valor da mediana imagens:
#
# *   [pb]:
# *   [cinza]:
# *   [color]:
#     * [R]
#     * [G]
#     * [B]

# %% [markdown]
# Inverta os valores de `imagem_pb`, e "plote" a figura.

# %% [markdown]
# Faça a média entre os valores `R`, `G` e `B` de `image_color`, e gere uma nova imagem e plot o resultado.
